# %% [markdown]
# # Análisis de presencialidad
# ## Operaciones
# ### Agosto - Septiembre 2023

# %% [markdown]
# **Autor: Francisco Tagliavini**
# <br>
# Fecha: 2023-10-18

# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'c:\\users\\ftagliavini\\documents\\gestion_de_proyectos\\jornada_trabajo\\2do_semestre_2023\\'
os.listdir(path)
# Out:
# ['cbarbalarga_2023-07-01_2023-07-31_controlAccesoPromedioDetalle.xls',
#  'cbarbalarga_2023-08-01_2023-08-31_controlAccesoPromedioDetalle.xls',
#  'cbarbalarga_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls',
#  'Consolidacion_prueba_septiembre2023.xlsx',
#  'dinsaurralde_2023-07-01_2023-07-31_controlAccesoPromedioDetalle.xls',
#  'dinsaurralde_2023-08-01_2023-08-31_controlAccesoPromedioDetalle.xls',
#  'dinsaurralde_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls',
#  'ecostales_2023-07-01_2023-07-31_controlAccesoPromedioDetalle.xls',
#  'ecostales_2023-08-01_2023-08-31_controlAccesoPromedioDetalle.xls',
#  'ecostales_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls',
#  'eosorio_2023-07-01_2023-07-31_controlAccesoPromedioDetalle.xls',
#  'eosorio_2023-08-01_2023-08-31_controlAccesoPromedioDetalle.xls',
#  'eosorio_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls',
#  'fselvaggi_2023-07-01_2023-07-31_controlAccesoPromedioDetalle.xls',
# ...

# %%
f_ceci = 'cbarbalarga_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_ceci = path + f_ceci
f_dani = 'dinsaurralde_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_dani = path + f_dani
f_edu = 'ecostales_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_edu = path + f_edu
f_ero = 'eosorio_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_ero = path + f_ero
f_fer = 'fselvaggi_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_fer = path + f_fer
f_manu = 'jsequeira_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_manu = path + f_manu
f_leo = 'landino_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_leo = path + f_leo
f_lucas = 'lncabrera_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_lucas = path + f_lucas
f_pan = 'pgortiz_2023-08-01_2023-09-30_controlAccesoPromedioDetalle.xls'
p_pan = path + f_pan

# %% [markdown]
# pip install xlrd

# %%
df_ceci = pd.read_excel(p_ceci)
df_dani = pd.read_excel(p_dani)
df_edu = pd.read_excel(p_edu)
df_ero = pd.read_excel(p_ero)
df_fer = pd.read_excel(p_fer)
df_manu = pd.read_excel(p_manu)
df_leo = pd.read_excel(p_leo)
df_lucas = pd.read_excel(p_lucas)
df_pan = pd.read_excel(p_pan)

# %% [raw]
# # personas = [ 'Cecilia Barbalarga','Daniel Insaurralde','Eduardo Costales','Edward Osorio','Fernando Selvaggi',
#               'Leonardo Andino','Lucas Cabrera','Juan M Sequeira','Pablo Ortiz']
# todos_los_df = [df_ceci,df_dani,df_edu,df_ero,df_fer,df_leo,df_lucas,df_manu,df_pan]
# operaciones = pd.DataFrame({personas : todos_los_df})
# operaciones.info()
# #
# #i=0
# #for empleado in operaciones:
# #
# calendario['n_semana_c'] = calendario.index.isocalendar().week
# calendario['n_dia_c'] = calendario.index.weekday
# calendario['dia'] = calendario.index.day_name()
# calendario['n_mes_c'] = calendario.index.month
# calendario['mes'] = calendario.index.month_name()
# #

# %%
df_ceci = df_ceci.loc[2:,:]
df_ceci.reset_index
df_ceci.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
#pd.to_datetime(df['Fecha'])
df_ceci['Fecha'] = pd.to_datetime(df_ceci['Fecha'])
df_ceci['Fecha'] = df_ceci['Fecha'].values.astype('datetime64[D]')
df_ceci['Nombre'] = 'Cecilia Barbalarga'

df_ceci.index = df_ceci['Fecha']
df_ceci['n_semana'] = df_ceci.index.isocalendar().week
df_ceci['n_dia'] = df_ceci.index.weekday
df_ceci['dia'] = df_ceci.index.day_name()
df_ceci['n_mes'] = df_ceci.index.month
df_ceci['mes'] = df_ceci.index.month_name()

vacios = df_ceci['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_ceci['Detalle'] = df_ceci.Detalle.fillna('Presencial')

df_ceci.head(1)
# Out:
# NaN encontrados 9
#                 Fecha     Dia Entrada Salida  Horas  \
# Fecha
# 2023-08-01 2023-08-01  Martes   07:20  13:40  06:20
#
#                                     Detalle    Estado              Nombre  \
# Fecha
# 2023-08-01  Trabajo remoto (Res. PGN 88/22)  Aprobada  Cecilia Barbalarga
#
#             n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01        31      1  Tuesday      8  August

# %%
df_dani = df_dani.loc[2:,:]
df_dani.reset_index
df_dani.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_dani['Fecha'] = pd.to_datetime(df_dani['Fecha'])
df_dani['Fecha'] = df_dani['Fecha'].values.astype('datetime64[D]')
df_dani['Nombre'] = 'Daniel Insaurralde'

df_dani.index = df_dani['Fecha']
df_dani['n_semana'] = df_dani.index.isocalendar().week
df_dani['n_dia'] = df_dani.index.weekday
df_dani['dia'] = df_dani.index.day_name()
df_dani['n_mes'] = df_dani.index.month
df_dani['mes'] = df_dani.index.month_name()

vacios = df_dani['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_dani['Detalle'] = df_dani.Detalle.fillna('Presencial')

df_dani.head(1)
# Out:
# NaN encontrados 6
#                 Fecha     Dia Entrada Salida  Horas                 Detalle  \
# Fecha
# 2023-08-01 2023-08-01  Martes     NaN    NaN  00:00  Compensación - Art. 13
#
#                Estado              Nombre  n_semana  n_dia      dia  n_mes  \
# Fecha
# 2023-08-01  Concedida  Daniel Insaurralde        31      1  Tuesday      8
#
#                mes
# Fecha
# 2023-08-01  August

# %%
df_edu = df_edu.loc[2:,:]
df_edu.reset_index
df_edu.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_edu['Fecha'] = pd.to_datetime(df_edu['Fecha'])
df_edu['Fecha'] = df_edu['Fecha'].values.astype('datetime64[D]')
df_edu['Nombre'] = 'Eduardo Costales'

df_edu.index = df_edu['Fecha']
df_edu['n_semana'] = df_edu.index.isocalendar().week
df_edu['n_dia'] = df_edu.index.weekday
df_edu['dia'] = df_edu.index.day_name()
df_edu['n_mes'] = df_edu.index.month
df_edu['mes'] = df_edu.index.month_name()

vacios = df_edu['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_edu['Detalle'] = df_edu.Detalle.fillna('Presencial')

df_edu.head(1)
# Out:
# NaN encontrados 22
#                 Fecha     Dia Entrada Salida  Horas     Detalle Estado  \
# Fecha
# 2023-08-01 2023-08-01  Martes   09:47  15:49  06:02  Presencial    NaN
#
#                       Nombre  n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01  Eduardo Costales        31      1  Tuesday      8  August

# %%
df_ero = df_ero.loc[2:,:]
df_ero.reset_index
df_ero.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_ero['Fecha'] = pd.to_datetime(df_ero['Fecha'])
df_ero['Fecha'] = df_ero['Fecha'].values.astype('datetime64[D]')
df_ero['Nombre'] = 'Edward Osorio'

df_ero.index = df_ero['Fecha']
df_ero['n_semana'] = df_ero.index.isocalendar().week
df_ero['n_dia'] = df_ero.index.weekday
df_ero['dia'] = df_ero.index.day_name()
df_ero['n_mes'] = df_ero.index.month
df_ero['mes'] = df_ero.index.month_name()

vacios = df_ero['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_ero['Detalle'] = df_ero.Detalle.fillna('Presencial')

df_ero.head(1)
# Out:
# NaN encontrados 26
#                 Fecha     Dia Entrada Salida  Horas  \
# Fecha
# 2023-08-01 2023-08-01  Martes   09:00  15:00  06:00
#
#                                     Detalle    Estado         Nombre  \
# Fecha
# 2023-08-01  Trabajo remoto (Res. PGN 88/22)  Aprobada  Edward Osorio
#
#             n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01        31      1  Tuesday      8  August

# %%
df_fer = df_fer.loc[2:,:]
df_fer.reset_index
df_fer.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_fer['Fecha'] = pd.to_datetime(df_fer['Fecha'])
df_fer['Fecha'] = df_fer['Fecha'].values.astype('datetime64[D]')
df_fer['Nombre'] = 'Fernando Sevaggi'

df_fer.index = df_fer['Fecha']
df_fer['n_semana'] = df_fer.index.isocalendar().week
df_fer['n_dia'] = df_fer.index.weekday
df_fer['dia'] = df_fer.index.day_name()
df_fer['n_mes'] = df_fer.index.month
df_fer['mes'] = df_fer.index.month_name()

vacios = df_fer['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_fer['Detalle'] = df_fer.Detalle.fillna('Presencial')

df_fer.head(1)
# Out:
# NaN encontrados 19
#                 Fecha     Dia Entrada Salida  Horas     Detalle Estado  \
# Fecha
# 2023-08-01 2023-08-01  Martes   09:09  15:18  06:09  Presencial    NaN
#
#                       Nombre  n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01  Fernando Sevaggi        31      1  Tuesday      8  August

# %%
df_manu = df_manu.loc[2:,:]
df_manu.reset_index
df_manu.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_manu['Fecha'] = pd.to_datetime(df_manu['Fecha'])
df_manu['Fecha'] = df_manu['Fecha'].values.astype('datetime64[D]')
df_manu['Nombre'] = 'Juan Sequeira'

df_manu.index = df_manu['Fecha']
df_manu['n_semana'] = df_manu.index.isocalendar().week
df_manu['n_dia'] = df_manu.index.weekday
df_manu['dia'] = df_manu.index.day_name()
df_manu['n_mes'] = df_manu.index.month
df_manu['mes'] = df_manu.index.month_name()

vacios = df_manu['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_manu['Detalle'] = df_manu.Detalle.fillna('Presencial')

df_manu.head(1)
# Out:
# NaN encontrados 20
#                 Fecha     Dia Entrada Salida  Horas  \
# Fecha
# 2023-08-01 2023-08-01  Martes     NaN    NaN  00:00
#
#                                      Detalle     Estado         Nombre  \
# Fecha
# 2023-08-01  Razones particulares - Art. 34 c  Concedida  Juan Sequeira
#
#             n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01        31      1  Tuesday      8  August

# %%
df_leo = df_leo.loc[2:,:]
df_leo.reset_index
df_leo.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_leo['Fecha'] = pd.to_datetime(df_leo['Fecha'])
df_leo['Fecha'] = df_leo['Fecha'].values.astype('datetime64[D]')
df_leo['Nombre'] = 'Leonardo Andino'

df_leo.index = df_leo['Fecha']
df_leo['n_semana'] = df_leo.index.isocalendar().week
df_leo['n_dia'] = df_leo.index.weekday
df_leo['dia'] = df_leo.index.day_name()
df_leo['n_mes'] = df_leo.index.month
df_leo['mes'] = df_leo.index.month_name()

vacios = df_leo['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_leo['Detalle'] = df_leo.Detalle.fillna('Presencial')

df_leo.head(1)
# Out:
# NaN encontrados 23
#                 Fecha     Dia Entrada Salida  Horas     Detalle Estado  \
# Fecha
# 2023-08-01 2023-08-01  Martes   11:24  17:38  06:14  Presencial    NaN
#
#                      Nombre  n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01  Leonardo Andino        31      1  Tuesday      8  August

# %%
df_lucas = df_lucas.loc[2:,:]
df_lucas.reset_index
df_lucas.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_lucas['Fecha'] = pd.to_datetime(df_lucas['Fecha'])
df_lucas['Fecha'] = df_lucas['Fecha'].values.astype('datetime64[D]')
df_lucas['Nombre'] = 'Lucas Cabrera'

df_lucas.index = df_lucas['Fecha']
df_lucas['n_semana'] = df_lucas.index.isocalendar().week
df_lucas['n_dia'] = df_lucas.index.weekday
df_lucas['dia'] = df_lucas.index.day_name()
df_lucas['n_mes'] = df_lucas.index.month
df_lucas['mes'] = df_lucas.index.month_name()

vacios = df_lucas['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_lucas['Detalle'] = df_lucas.Detalle.fillna('Presencial')

df_lucas.head(1)
# Out:
# NaN encontrados 21
#                 Fecha     Dia Entrada Salida  Horas     Detalle Estado  \
# Fecha
# 2023-08-01 2023-08-01  Martes   08:51  15:17  06:26  Presencial    NaN
#
#                    Nombre  n_semana  n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01  Lucas Cabrera        31      1  Tuesday      8  August

# %%
df_pan = df_pan.loc[2:,:]
df_pan.reset_index
df_pan.columns = ['Fecha','Dia','Entrada','Salida','Horas','Detalle','Estado']
df_pan['Fecha'] = pd.to_datetime(df_pan['Fecha'])
df_pan['Fecha'] = df_pan['Fecha'].values.astype('datetime64[D]')
df_pan['Nombre'] = 'Pablo Ortiz'

df_pan.index = df_pan['Fecha']
df_pan['n_semana'] = df_pan.index.isocalendar().week
df_pan['n_dia'] = df_pan.index.weekday
df_pan['dia'] = df_pan.index.day_name()
df_pan['n_mes'] = df_pan.index.month
df_pan['mes'] = df_pan.index.month_name()

vacios = df_pan['Detalle'].isna().sum()
print(f'NaN encontrados', vacios)
df_pan['Detalle'] = df_pan.Detalle.fillna('Presencial')

df_pan.head(1)
# Out:
# NaN encontrados 14
#                 Fecha     Dia Entrada Salida  Horas  \
# Fecha
# 2023-08-01 2023-08-01  Martes   10:00  17:00  07:00
#
#                                     Detalle    Estado       Nombre  n_semana  \
# Fecha
# 2023-08-01  Trabajo remoto (Res. PGN 88/22)  Aprobada  Pablo Ortiz        31
#
#             n_dia      dia  n_mes     mes
# Fecha
# 2023-08-01      1  Tuesday      8  August

# %%
df = pd.concat([df_ceci,df_dani,df_edu,df_ero,df_fer,df_manu,df_leo,df_lucas,df_pan],ignore_index=True)
#df.concat
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     392 non-null    datetime64[s]
#  1   Dia       392 non-null    object
#  2   Entrada   331 non-null    object
#  3   Salida    331 non-null    object
#  4   Horas     392 non-null    object
#  5   Detalle   392 non-null    object
#  6   Estado    212 non-null    object
#  7   Nombre    392 non-null    object
#  8   n_semana  392 non-null    UInt32
#  9   n_dia     392 non-null    int32
#  10  dia       392 non-null    object
#  11  n_mes     392 non-null    int32
#  12  mes       392 non-null    object
# dtypes: UInt32(1), datetime64[s](1), int32(2), object(9)
# memory usage: 35.7+ KB

# %%
#df['Fecha'] = pd.to_datetime(df['Fecha']).values.astype('datetime64[D]')
df.head(1)
# Out:
#        Fecha     Dia Entrada Salida  Horas                          Detalle  \
# 0 2023-08-01  Martes   07:20  13:40  06:20  Trabajo remoto (Res. PGN 88/22)
#
#      Estado              Nombre  n_semana  n_dia      dia  n_mes     mes
# 0  Aprobada  Cecilia Barbalarga        31      1  Tuesday      8  August

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     392 non-null    datetime64[s]
#  1   Dia       392 non-null    object
#  2   Entrada   331 non-null    object
#  3   Salida    331 non-null    object
#  4   Horas     392 non-null    object
#  5   Detalle   392 non-null    object
#  6   Estado    212 non-null    object
#  7   Nombre    392 non-null    object
#  8   n_semana  392 non-null    UInt32
#  9   n_dia     392 non-null    int32
#  10  dia       392 non-null    object
#  11  n_mes     392 non-null    int32
#  12  mes       392 non-null    object
# dtypes: UInt32(1), datetime64[s](1), int32(2), object(9)
# memory usage: 35.7+ KB

# %% [raw]
# df['n_dia'] = df.Fecha.dt.weekday

# %% [raw]
# df['semana'] = df.Fecha.dt.isocalendar().week

# %% [raw]
# df.head(1)

# %% [markdown]
# df['Detalle'].isna().sum()

# %% [markdown]
# df.Detalle = df.Detalle.fillna('Presencial')
# df

# %% [raw]
# df['Detalle'].isna().sum()

# %% [markdown]
# df_ceci_1 = df.loc[(df['Nombre'] == 'Cecilia Barbalarga'),['Fecha','Detalle','semana','n_dia']]

# %% [markdown]
# df_ceci_1.head(1)

# %% [markdown]
# df_ceci_1['Fecha'] = df_ceci_1['Fecha'].values.astype('datetime64[D]')

# %% [markdown]
# df_ceci_1.index = df_ceci_1['Fecha']

# %% [raw]
# df.index = df['Fecha']
# df.head()

# %%
calendario_index = pd.date_range(start="2023-08-01", end="2023-09-30", freq="D")

# %%
calendario_index = calendario_index.values.astype('datetime64[D]')

# %%
calendario = pd.DataFrame(index=calendario_index)

# %%
calendario['n_semana_c'] = calendario.index.isocalendar().week
calendario['n_dia_c'] = calendario.index.weekday
calendario['dia_c'] = calendario.index.day_name()
calendario['n_mes_c'] = calendario.index.month
calendario['mes_c'] = calendario.index.month_name()

# %%
calendario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61 entries, 2023-08-01 to 2023-09-30
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   n_semana_c  61 non-null     UInt32
#  1   n_dia_c     61 non-null     int32
#  2   dia_c       61 non-null     object
#  3   n_mes_c     61 non-null     int32
#  4   mes_c       61 non-null     object
# dtypes: UInt32(1), int32(2), object(2)
# memory usage: 2.2+ KB

# %%
calendario.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c
# 2023-08-01          31        1    Tuesday        8  August
# 2023-08-02          31        2  Wednesday        8  August
# 2023-08-03          31        3   Thursday        8  August
# 2023-08-04          31        4     Friday        8  August
# 2023-08-05          31        5   Saturday        8  August

# %%
personas = [ 'Cecilia_Barbalarga','Daniel_Insaurralde','Eduardo_Costales','Edward_Osorio','Fernando_Selvaggi',
              'Leonardo_Andino','Lucas_Cabrera','Juan_M_Sequeira','Pablo_G_Ortiz']
operaciones = [df_ceci,df_dani,df_edu,df_ero,df_fer,df_leo,df_lucas,df_manu,df_pan]

# %%
#labels = df['Detalle'].unique()
plt.style.use('bmh')
i=0
for empleado in operaciones:
    detalle = empleado['Detalle'].value_counts()
    etiquetas = empleado['Detalle'].unique()
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.pie(detalle,autopct='%.1f%%')
    plt.title(personas[i])
    fig.legend(loc='outside right',title='Detalles',labels=etiquetas)
    imagen='detalle_'+ personas[i] + '.png'
    plt.savefig(imagen,format='png')
    plt.show()
    
    i += 1

# %%
df_ceci['Detalle'].value_counts()
# Out:
# Detalle
# Trabajo remoto (Res. PGN 88/22)           31
# Presencial                                 9
# Presto funciones en dia no habil           2
# Atención de familiar enfermo - Art. 25     2
# Razones particulares - Art. 34 c           1
# Name: count, dtype: int64

# %%
df_dani['Detalle'].value_counts()
# Out:
# Detalle
# Compensación - Art. 13                        25
# Presencial                                     6
# Trabajo remoto (Res. PGN 88/22)                5
# Razones particulares - Art. 34 c               2
# Inasistencia justificada                       2
# Enfermedades o tratamientos de corto plazo     2
# Justificado                                    1
# Name: count, dtype: int64

# %%
df_edu['Detalle'].value_counts()
# Out:
# Detalle
# Presencial                          22
# Trabajo remoto (Res. PGN 88/22)     15
# Inasistencia justificada             4
# Justificado                          1
# Razones particulares - Art. 34 c     1
# Name: count, dtype: int64

# %%
df_ero['Detalle'].value_counts()
# Out:
# Detalle
# Presencial                         26
# Trabajo remoto (Res. PGN 88/22)    17
# Name: count, dtype: int64

# %%
df_fer['Detalle'].value_counts()
# Out:
# Detalle
# Trabajo remoto (Res. PGN 88/22)               21
# Presencial                                    19
# Presto funciones en dia no habil               2
# Enfermedades o tratamientos de corto plazo     2
# Inasistencia justificada                       1
# Name: count, dtype: int64

# %%
df_leo['Detalle'].value_counts()
# Out:
# Detalle
# Presencial                         23
# Trabajo remoto (Res. PGN 88/22)    16
# Inasistencia justificada            4
# Name: count, dtype: int64

# %%
df_manu['Detalle'].value_counts()
# Out:
# Detalle
# Presencial                          20
# Trabajo remoto (Res. PGN 88/22)     19
# Inasistencia justificada             3
# Razones particulares - Art. 34 c     1
# Name: count, dtype: int64

# %%
df_lucas['Detalle'].value_counts()
# Out:
# Detalle
# Presencial                                        21
# Trabajo remoto (Res. PGN 88/22)                   15
# Error u omisión de fichada de ingreso o egreso     2
# Inasistencia justificada                           2
# Compensación - Art. 13                             2
# Justificado                                        1
# Name: count, dtype: int64

# %%
df_pan['Detalle'].value_counts()
# Out:
# Detalle
# Trabajo remoto (Res. PGN 88/22)     22
# Presencial                          14
# Compensación - Art. 13               5
# Inasistencia justificada             1
# Presto funciones en dia no habil     1
# Razones particulares - Art. 34 c     1
# Name: count, dtype: int64

# %%
cronograma_ceci = df_ceci.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_ceci
# Out:
#                                                    Dia             \
# Detalle         Atención de familiar enfermo - Art. 25 Presencial
# n_dia dia
# 0     Monday                                         1          5
# 1     Tuesday                                        1          4
# 2     Wednesday                                      0          0
# 3     Thursday                                       0          0
# 4     Friday                                         0          0
# 5     Saturday                                       0          0
# 6     Sunday                                         0          0
#
#                                                   \
# Detalle         Presto funciones en dia no habil
# n_dia dia
# 0     Monday                                   0
# 1     Tuesday                                  0
# 2     Wednesday                                0
# 3     Thursday                                 0
# ...

# %%
cronograma_dani = df_dani.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_dani
# Out:
#                                    Dia  \
# Detalle         Compensación - Art. 13
# n_dia dia
# 0     Monday                         4
# 1     Tuesday                        6
# 2     Wednesday                      6
# 3     Thursday                       5
# 4     Friday                         4
#
#                                                             \
# Detalle         Enfermedades o tratamientos de corto plazo
# n_dia dia
# 0     Monday                                             0
# 1     Tuesday                                            0
# 2     Wednesday                                          1
# 3     Thursday                                           1
# 4     Friday                                             0
#
#                                                                  \
# Detalle         Inasistencia justificada Justificado Presencial
# n_dia dia
# 0     Monday                           0           0          0
# ...

# %%
cronograma_edu = df_edu.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_edu
# Out:
#                                      Dia                         \
# Detalle         Inasistencia justificada Justificado Presencial
# n_dia dia
# 0     Monday                           0           0          2
# 1     Tuesday                          0           0          7
# 2     Wednesday                        0           1          0
# 3     Thursday                         1           0          7
# 4     Friday                           3           0          6
#
#                                                   \
# Detalle         Razones particulares - Art. 34 c
# n_dia dia
# 0     Monday                                   0
# 1     Tuesday                                  1
# 2     Wednesday                                0
# 3     Thursday                                 0
# 4     Friday                                   0
#
#
# Detalle         Trabajo remoto (Res. PGN 88/22)
# n_dia dia
# 0     Monday                                  5
# ...

# %%
cronograma_ero = df_ero.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_ero
# Out:
#                        Dia
# Detalle         Presencial Trabajo remoto (Res. PGN 88/22)
# n_dia dia
# 0     Monday             6                               1
# 1     Tuesday            5                               4
# 2     Wednesday          6                               3
# 3     Thursday           4                               5
# 4     Friday             5                               4

# %%
cronograma_fer = df_fer.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_fer
# Out:
#                                                        Dia  \
# Detalle         Enfermedades o tratamientos de corto plazo
# n_dia dia
# 0     Monday                                             0
# 1     Tuesday                                            0
# 2     Wednesday                                          0
# 3     Thursday                                           1
# 4     Friday                                             1
# 5     Saturday                                           0
# 6     Sunday                                             0
#
#                                                      \
# Detalle         Inasistencia justificada Presencial
# n_dia dia
# 0     Monday                           0          3
# 1     Tuesday                          0          6
# 2     Wednesday                        1          7
# 3     Thursday                         0          2
# 4     Friday                           0          1
# ...

# %%
cronograma_leo = df_leo.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_leo
# Out:
#                                      Dia             \
# Detalle         Inasistencia justificada Presencial
# n_dia dia
# 0     Monday                           0          0
# 1     Tuesday                          0          7
# 2     Wednesday                        1          8
# 3     Thursday                         0          8
# 4     Friday                           3          0
#
#
# Detalle         Trabajo remoto (Res. PGN 88/22)
# n_dia dia
# 0     Monday                                  7
# 1     Tuesday                                 2
# 2     Wednesday                               0
# 3     Thursday                                1
# 4     Friday                                  6

# %%
cronograma_manu = df_manu.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_manu
# Out:
#                                      Dia             \
# Detalle         Inasistencia justificada Presencial
# n_dia dia
# 0     Monday                           0          0
# 1     Tuesday                          0          7
# 2     Wednesday                        0          1
# 3     Thursday                         0          8
# 4     Friday                           3          4
#
#                                                   \
# Detalle         Razones particulares - Art. 34 c
# n_dia dia
# 0     Monday                                   0
# 1     Tuesday                                  1
# 2     Wednesday                                0
# 3     Thursday                                 0
# 4     Friday                                   0
#
#
# Detalle         Trabajo remoto (Res. PGN 88/22)
# n_dia dia
# 0     Monday                                  7
# 1     Tuesday                                 1
# 2     Wednesday                               8
# ...

# %%
cronograma_lucas = df_lucas.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_lucas
# Out:
#                                    Dia  \
# Detalle         Compensación - Art. 13
# n_dia dia
# 0     Monday                         0
# 1     Tuesday                        0
# 2     Wednesday                      0
# 3     Thursday                       1
# 4     Friday                         1
#
#                                                                 \
# Detalle         Error u omisión de fichada de ingreso o egreso
# n_dia dia
# 0     Monday                                                 0
# 1     Tuesday                                                0
# 2     Wednesday                                              0
# 3     Thursday                                               2
# 4     Friday                                                 0
#
#                                                                  \
# Detalle         Inasistencia justificada Justificado Presencial
# n_dia dia
# 0     Monday                           0           0          0
# ...

# %%
cronograma_pan = df_pan.pivot_table(index=['n_dia','dia'],columns=['Detalle'],aggfunc={'Dia' : 'count'}, fill_value=0)
cronograma_pan
# Out:
#                                    Dia                                      \
# Detalle         Compensación - Art. 13 Inasistencia justificada Presencial
# n_dia dia
# 0     Monday                         1                        0          4
# 1     Tuesday                        1                        0          1
# 2     Wednesday                      1                        0          5
# 3     Thursday                       1                        1          1
# 4     Friday                         1                        0          3
# 5     Saturday                       0                        0          0
#
#                                                   \
# Detalle         Presto funciones en dia no habil
# n_dia dia
# 0     Monday                                   0
# 1     Tuesday                                  0
# 2     Wednesday                                0
# 3     Thursday                                 0
# ...

# %%
semanal_ceci = pd.concat([calendario, df_ceci], ignore_index=False,axis=1)
semanal_ceci.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   07:20  13:40  06:20  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Miércoles   07:25  14:20  06:55  Trabajo remoto (Res. PGN 88/22)
# 2023-08-03     Jueves   07:30  19:55  12:25  Trabajo remoto (Res. PGN 88/22)
# 2023-08-04    Viernes   07:20  14:05  06:45  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %%
semanal_dani = pd.concat([calendario, df_dani], ignore_index=False,axis=1)
semanal_dani.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                 Detalle  \
# 2023-08-01     Martes     NaN    NaN  00:00  Compensación - Art. 13
# 2023-08-02  Miércoles     NaN    NaN  00:00  Compensación - Art. 13
# 2023-08-03     Jueves     NaN    NaN  00:00  Compensación - Art. 13
# 2023-08-04    Viernes     NaN    NaN  00:00  Compensación - Art. 13
# 2023-08-05        NaN     NaN    NaN    NaN                     NaN
#
#                Estado              Nombre  n_semana  n_dia        dia  n_mes  \
# ...

# %%
semanal_edu = pd.concat([calendario, df_edu], ignore_index=False,axis=1)
semanal_edu.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   09:47  15:49  06:02                       Presencial
# 2023-08-02  Miércoles   09:00  15:00  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-03     Jueves   10:52  17:38  06:46                       Presencial
# 2023-08-04    Viernes   10:28  16:30  06:02                       Presencial
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %%
semanal_ero = pd.concat([calendario, df_ero], ignore_index=False,axis=1)
semanal_ero.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   09:00  15:00  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Miércoles   07:55  14:01  06:06                       Presencial
# 2023-08-03     Jueves   07:33  14:09  06:36                       Presencial
# 2023-08-04    Viernes   09:00  15:00  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %%
semanal_fer = pd.concat([calendario, df_fer], ignore_index=False,axis=1)
semanal_fer.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   09:09  15:18  06:09                       Presencial
# 2023-08-02  Miércoles   09:24  15:53  06:29                       Presencial
# 2023-08-03     Jueves   09:10  23:00  13:50  Trabajo remoto (Res. PGN 88/22)
# 2023-08-04    Viernes   09:00  15:00  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %%
semanal_leo = pd.concat([calendario, df_leo], ignore_index=False,axis=1)
semanal_leo.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   11:24  17:38  06:14                       Presencial
# 2023-08-02  Miércoles   11:26  17:32  06:06                       Presencial
# 2023-08-03     Jueves   11:26  17:34  06:08                       Presencial
# 2023-08-04    Viernes   11:30  17:30  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
#               Estado           Nombre  n_semana  n_dia        dia  n_mes  \
# ...

# %%
semanal_manu = pd.concat([calendario, df_manu], ignore_index=False,axis=1)
semanal_manu.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                           Detalle  \
# 2023-08-01     Martes     NaN    NaN  00:00  Razones particulares - Art. 34 c
# 2023-08-02  Miércoles   09:00  15:00  06:00   Trabajo remoto (Res. PGN 88/22)
# 2023-08-03     Jueves   10:18  17:34  07:16                        Presencial
# 2023-08-04    Viernes   09:49  15:49  06:00                        Presencial
# 2023-08-05        NaN     NaN    NaN    NaN                               NaN
#
# ...

# %%
semanal_lucas = pd.concat([calendario, df_lucas], ignore_index=False,axis=1)
semanal_lucas.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   08:51  15:17  06:26                       Presencial
# 2023-08-02  Miércoles   08:43  15:18  06:35                       Presencial
# 2023-08-03     Jueves   10:29  17:37  07:08                       Presencial
# 2023-08-04    Viernes   09:00  15:00  06:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %%
semanal_pan = pd.concat([calendario, df_pan], ignore_index=False,axis=1)
semanal_pan.head()
# Out:
#             n_semana_c  n_dia_c      dia_c  n_mes_c   mes_c      Fecha  \
# 2023-08-01          31        1    Tuesday        8  August 2023-08-01
# 2023-08-02          31        2  Wednesday        8  August 2023-08-02
# 2023-08-03          31        3   Thursday        8  August 2023-08-03
# 2023-08-04          31        4     Friday        8  August 2023-08-04
# 2023-08-05          31        5   Saturday        8  August        NaT
#
#                   Dia Entrada Salida  Horas                          Detalle  \
# 2023-08-01     Martes   10:00  17:00  07:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Miércoles   10:13  16:24  06:11                       Presencial
# 2023-08-03     Jueves   10:11  18:05  07:54                       Presencial
# 2023-08-04    Viernes   10:00  17:00  07:00  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05        NaN     NaN    NaN    NaN                              NaN
#
# ...

# %% [raw]
# semanal_ceci[['mes_c','n_semana_c','n_dia_c','dia_c','Detalle']]

# %%
weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
semanales = [semanal_ceci, semanal_dani,semanal_edu,semanal_ero,semanal_fer,semanal_leo,
             semanal_manu,semanal_lucas,semanal_pan]

# %%
i=0
for empleado in semanales:
    fig, ax = plt.subplots(figsize=(12, 6))
    sns.countplot(data=empleado,x='dia_c',hue='Detalle',ax=ax,order=weekday_order)
    titulo = personas[i] + '- Ago-Sept 2023 -'
    ax.set(title=titulo,xlabel='dias de la semana',ylabel='ocurrencias acumuladas')
    imagen='semanal_'+ personas[i] + '.png'
    plt.savefig(imagen,format='png')
    plt.show()
    
    i +=1
# Out:
# C:\ProgramData\miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
s_c_31 = semanal_ceci.loc[(semanal_ceci['n_semana_c'] == 31),['Detalle']]
s_c_31
# Out:
#                                     Detalle
# 2023-08-01  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Trabajo remoto (Res. PGN 88/22)
# 2023-08-03  Trabajo remoto (Res. PGN 88/22)
# 2023-08-04  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05                              NaN
# 2023-08-06                              NaN

# %%
num_semana = calendario.n_semana_c.unique()
num_semana
# Out:
# <IntegerArray>
# [31, 32, 33, 34, 35, 36, 37, 38, 39]
# Length: 9, dtype: UInt32

# %%
print('Cecilia Barbalarga')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_ceci.loc[(semanal_ceci['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Cecilia Barbalarga
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Wednesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-03   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                           Detalle
# 2023-08-07     Monday                        Presencial
# 2023-08-08    Tuesday                        Presencial
# 2023-08-09  Wednesday   Trabajo remoto (Res. PGN 88/22)
# 2023-08-10   Thursday   Trabajo remoto (Res. PGN 88/22)
# 2023-08-11     Friday   Trabajo remoto (Res. PGN 88/22)
# 2023-08-12   Saturday  Presto funciones en dia no habil
# ...

# %%
print('Daniel Insaurralde')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_dani.loc[(semanal_dani['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Daniel Insaurralde
# ---------------------
# Número de semana:  31
#                 dia_c                 Detalle
# 2023-08-01    Tuesday  Compensación - Art. 13
# 2023-08-02  Wednesday  Compensación - Art. 13
# 2023-08-03   Thursday  Compensación - Art. 13
# 2023-08-04     Friday  Compensación - Art. 13
# 2023-08-05   Saturday                     NaN
# 2023-08-06     Sunday                     NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                 Detalle
# 2023-08-07     Monday  Compensación - Art. 13
# 2023-08-08    Tuesday  Compensación - Art. 13
# 2023-08-09  Wednesday  Compensación - Art. 13
# 2023-08-10   Thursday  Compensación - Art. 13
# 2023-08-11     Friday  Compensación - Art. 13
# 2023-08-12   Saturday                     NaN
# 2023-08-13     Sunday                     NaN
# ------------------------------------------------------------
# Número de semana:  33
# ...

# %%
print('Eduardo Costales')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_edu.loc[(semanal_edu['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Eduardo Costales
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday                       Presencial
# 2023-08-02  Wednesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-03   Thursday                       Presencial
# 2023-08-04     Friday                       Presencial
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-08    Tuesday                       Presencial
# 2023-08-09  Wednesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-10   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-11     Friday                       Presencial
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Edward Osorio')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_ero.loc[(semanal_ero['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Edward Osorio
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Wednesday                       Presencial
# 2023-08-03   Thursday                       Presencial
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday                       Presencial
# 2023-08-08    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-09  Wednesday                       Presencial
# 2023-08-10   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-11     Friday                       Presencial
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Fernando Selaggi')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_fer.loc[(semanal_fer['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Fernando Selaggi
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday                       Presencial
# 2023-08-02  Wednesday                       Presencial
# 2023-08-03   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday                       Presencial
# 2023-08-08    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-09  Wednesday                       Presencial
# 2023-08-10   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-11     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Leonardo Andino')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_leo.loc[(semanal_leo['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Leonardo Andino
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday                       Presencial
# 2023-08-02  Wednesday                       Presencial
# 2023-08-03   Thursday                       Presencial
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-08    Tuesday                       Presencial
# 2023-08-09  Wednesday                       Presencial
# 2023-08-10   Thursday                       Presencial
# 2023-08-11     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Juan M Sequeira')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_manu.loc[(semanal_manu['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Juan M Sequeira
# ---------------------
# Número de semana:  31
#                 dia_c                           Detalle
# 2023-08-01    Tuesday  Razones particulares - Art. 34 c
# 2023-08-02  Wednesday   Trabajo remoto (Res. PGN 88/22)
# 2023-08-03   Thursday                        Presencial
# 2023-08-04     Friday                        Presencial
# 2023-08-05   Saturday                               NaN
# 2023-08-06     Sunday                               NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-08    Tuesday                       Presencial
# 2023-08-09  Wednesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-10   Thursday                       Presencial
# 2023-08-11     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Lucas Cabrera')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_lucas.loc[(semanal_lucas['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Lucas Cabrera
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday                       Presencial
# 2023-08-02  Wednesday                       Presencial
# 2023-08-03   Thursday                       Presencial
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-08    Tuesday                       Presencial
# 2023-08-09  Wednesday                       Presencial
# 2023-08-10   Thursday                       Presencial
# 2023-08-11     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-12   Saturday                              NaN
# ...

# %%
print('Pablo G Ortiz')
print('---------------------')
for semana in num_semana:
    print('Número de semana: ',semana)
    tabla = semanal_pan.loc[(semanal_pan['n_semana_c'] == semana),['dia_c','Detalle']]
    #tabla.plot(kind='bar', x='dia_c')
    print(tabla)
    print('------------------------------------------------------------')
# Out:
# Pablo G Ortiz
# ---------------------
# Número de semana:  31
#                 dia_c                          Detalle
# 2023-08-01    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-02  Wednesday                       Presencial
# 2023-08-03   Thursday                       Presencial
# 2023-08-04     Friday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-05   Saturday                              NaN
# 2023-08-06     Sunday                              NaN
# ------------------------------------------------------------
# Número de semana:  32
#                 dia_c                          Detalle
# 2023-08-07     Monday                       Presencial
# 2023-08-08    Tuesday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-09  Wednesday                       Presencial
# 2023-08-10   Thursday  Trabajo remoto (Res. PGN 88/22)
# 2023-08-11     Friday                       Presencial
# 2023-08-12   Saturday                              NaN
# ...

# %%
semanal_ceci.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                        Detalle
# n_semana_c                                  31 32 33 34 35 36 37 38 39
# Detalle
# Atención de familiar enfermo - Art. 25       0  0  0  0  2  0  0  0  0
# Presencial                                   0  2  0  1  0  2  1  2  1
# Presto funciones en dia no habil             0  1  0  0  0  1  0  0  0
# Razones particulares - Art. 34 c             0  0  0  1  0  0  0  0  0
# Trabajo remoto (Res. PGN 88/22)              4  3  5  2  3  3  4  3  4

# %%
semanal_dani.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                            Detalle
# n_semana_c                                      31 32 33 34 35 36 37 38 39
# Detalle
# Compensación - Art. 13                           4  5  5  4  4  0  0  0  3
# Enfermedades o tratamientos de corto plazo       0  0  0  0  0  0  2  0  0
# Inasistencia justificada                         0  0  0  0  0  1  0  0  1
# Justificado                                      0  0  0  0  0  1  0  0  0
# Presencial                                       0  0  0  0  0  2  1  3  0
# Razones particulares - Art. 34 c                 0  0  0  0  1  0  0  1  0
# Trabajo remoto (Res. PGN 88/22)                  0  0  0  0  0  1  2  1  1

# %%
semanal_edu.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                  Detalle
# n_semana_c                            31 32 33 34 35 36 37 38 39
# Detalle
# Inasistencia justificada               0  0  0  1  0  1  0  0  2
# Justificado                            0  0  0  0  0  1  0  0  0
# Presencial                             3  2  3  2  3  2  3  3  1
# Razones particulares - Art. 34 c       0  0  0  0  0  0  0  0  1
# Trabajo remoto (Res. PGN 88/22)        1  3  2  1  2  1  2  2  1

# %%
semanal_ero.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                 Detalle
# n_semana_c                           31 32 33 34 35 36 37 38 39
# Detalle
# Presencial                            2  3  3  3  3  3  3  3  3
# Trabajo remoto (Res. PGN 88/22)       2  2  2  1  2  2  2  2  2

# %%
semanal_fer.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                            Detalle
# n_semana_c                                      31 32 33 34 35 36 37 38 39
# Detalle
# Enfermedades o tratamientos de corto plazo       0  0  0  0  0  0  0  2  0
# Inasistencia justificada                         0  0  0  0  0  1  0  0  0
# Presencial                                       2  2  3  2  3  2  0  2  3
# Presto funciones en dia no habil                 0  0  0  0  1  0  0  1  0
# Trabajo remoto (Res. PGN 88/22)                  2  3  2  2  2  2  5  1  2

# %%
semanal_leo.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                 Detalle
# n_semana_c                           31 32 33 34 35 36 37 38 39
# Detalle
# Inasistencia justificada              0  0  0  1  0  2  0  0  1
# Presencial                            3  3  3  3  3  2  3  1  2
# Trabajo remoto (Res. PGN 88/22)       1  2  2  0  2  1  2  4  2

# %%
semanal_manu.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                  Detalle
# n_semana_c                            31 32 33 34 35 36 37 38 39
# Detalle
# Inasistencia justificada               0  0  0  1  0  1  0  0  1
# Presencial                             2  2  2  2  3  2  2  3  2
# Razones particulares - Art. 34 c       1  0  0  0  0  0  0  0  0
# Trabajo remoto (Res. PGN 88/22)        1  3  3  1  2  2  3  2  2

# %%
semanal_lucas.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                                Detalle
# n_semana_c                                          31 32 33 34 35 36 37 38 39
# Detalle
# Compensación - Art. 13                               0  0  0  0  0  0  0  0  2
# Error u omisión de fichada de ingreso o egreso       0  0  1  0  0  0  0  1  0
# Inasistencia justificada                             0  0  0  1  0  1  0  0  0
# Justificado                                          0  0  0  0  0  1  0  0  0
# Presencial                                           3  3  2  2  3  2  2  2  2
# Trabajo remoto (Res. PGN 88/22)                      1  2  2  1  2  1  3  2  1

# %%
semanal_pan.pivot_table(index=['Detalle'],columns=['n_semana_c'],aggfunc={'Detalle' : 'count'}, fill_value=0)
# Out:
#                                  Detalle
# n_semana_c                            31 32 33 34 35 36 37 38 39
# Detalle
# Compensación - Art. 13                 0  0  0  0  0  0  5  0  0
# Inasistencia justificada               0  0  0  0  1  0  0  0  0
# Presencial                             2  3  2  1  3  2  0  1  0
# Presto funciones en dia no habil       0  0  0  0  1  0  0  0  0
# Razones particulares - Art. 34 c       0  0  0  0  0  1  0  0  0
# Trabajo remoto (Res. PGN 88/22)        2  2  3  3  1  2  0  4  5
