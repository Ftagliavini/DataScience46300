# %%
import requests
import json
import pandas as pd

# %%
# url = ''

# respuesta = requests.get(url)

# print(respuesta)

# respuesta.text

# texto = respuesta.text

# json.loads(texto)

# jsondata = json.loads(texto)

# df = pd.DataFrame.from_dict(jsondata)

# df.head()

# pd.read_json()

# %%
#url = 'https://api.estadisticasbcra.com'
url = 'https://api.estadisticasbcra.com/tasa_prestamos_personales'
#
headers = {"Authorization":"BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MzUxNTg1NjQsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJmdGFnbGlhdmluaUBnbWFpbC5jb20ifQ.FusgquXe0dPs0jzkgiMgVL97iMPYlr5u2iscOhVQ408_XhFZoMNV_RAkRYMhcDLtQE8GEBUg1qgAJBZhDn3kvg"}

response = requests.get(url,headers=headers)

response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# [{'d': '2010-07-01', 'v': 27.84}, {'d': '2010-07-02', 'v': 28.04}, {'d': '2010-07-05', 'v': 28.33}, {'d': '2010-07-06', 'v': 29.31}, {'d': '2010-07-07', 'v': 29.53}, {'d': '2010-07-08', 'v': 30.09}, {'d': '2010-07-12', 'v': 30.08}, {'d': '2010-07-13', 'v': 29.94}, {'d': '2010-07-14', 'v': 30.65}, {'d': '2010-07-15', 'v': 30.21}, {'d': '2010-07-16', 'v': 30.35}, {'d': '2010-07-19', 'v': 30.5}, {'d': '2010-07-20', 'v': 30.07}, {'d': '2010-07-21', 'v': 29.68}, {'d': '2010-07-22', 'v': 29.55}, {'d': '2010-07-23', 'v': 30.17}, {'d': '2010-07-26', 'v': 30.23}, {'d': '2010-07-27', 'v': 29.45}, {'d': '2010-07-28', 'v': 29.56}, {'d': '2010-07-29', 'v': 28.88}, {'d': '2010-07-30', 'v': 29.25}, {'d': '2010-08-02', 'v': 28.61}, {'d': '2010-08-03', 'v': 27.58}, {'d': '2010-08-04', 'v': 28.58}, {'d': '2010-08-05', 'v': 29.76}, {'d': '2010-08-06', 'v': 29.62}, {'d': '2010-08-09', 'v': 29.99}, {'d': '2010-08-10', 'v': 30.01}, {'d': '2010-08-11', 'v': 29.65}, {'d': '2010-08-12', 'v': 29.88}, {'d': '2
# ...

# %%
data = response.json()
df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#             d      v
# 0  2010-07-01  27.84
# 1  2010-07-02  28.04
# 2  2010-07-05  28.33
# 3  2010-07-06  29.31
# 4  2010-07-07  29.53

# %%
df.plot()
# Out:
# <Axes: >

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (3284, 2)
