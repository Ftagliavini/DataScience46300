# %% [markdown]
# # Pequeño asistente virtual

# %% [markdown]
# ## Texto a audio

# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS('En el corazón de cada desafío yace una oportunidad para crecer, aprender y descubrir la fuerza que reside dentro de nosotros.',lang='es')
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS('Believe in the magic within you.',lang='en')
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Clima

# %%
import requests
from bs4 import BeautifulSoup

# Ciudad de Argentina
city = "Buenos Aires"

# Creando una instancia a partir de la URL y obteniendo el contenido.
url = "https://www.google.com/search?q="+"weather"+city
html = requests.get(url).content

# # Obtener la data con BeautifulSoup
# Beautiful Soup is a Python library for pulling data out of HTML and XML files
soup = BeautifulSoup(html, 'html.parser')
temp = soup.find('div', attrs={'class': 'BNeawe iBp4i AP7Wnd'}).text
str = soup.find('div', attrs={'class': 'BNeawe tAd8D AP7Wnd'}).text
# print(temp)
# print(str)
# # Formatear la data
data = str.split('\n')
# print(data)
time = data[0]
sky = data[1]

# # # Mostrar la data
print("Temperatura es", temp)
print("Tiempo: ", time)
print("Descripcion del cielo: ", sky)
# Out:
# Temperatura es 66°F
# Tiempo:  Wednesday 9:20 PM
# Descripcion del cielo:  Clear with periodic clouds

# %% [markdown]
# # Imagen a texto

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# ...

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en dr
import os
print(os.getcwd())
os.chdir("/content/gdrive/My Drive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/CoderHouse/46300/Clase 18 - Introducción al ML y la IA

# %%
cd "/content/gdrive/My Drive/CoderHouse/46300/Clase 18 - Introducción al ML y la IA"
# Out:
# /content/gdrive/My Drive/CoderHouse/46300/Clase 18 - Introducción al ML y la IA

# %%
import pytesseract
from PIL import Image
text = pytesseract.image_to_string(Image.open('imagen_prueba.jpg'))
# print(text)
tts = gTTS(text,lang='en')
tts.save('2.wav')
sound_file = '2.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Para poder leer en español debemos instalar primero el lenguaje

# %%
# !sudo apt-get install tesseract-ocr-spa
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
text2 = pytesseract.image_to_string(Image.open('imagen_prueba1.jpg'),
                                    lang="spa")
print(text1)
# tts = gTTS(text2,lang='es')
# tts.save('3.wav')
# sound_file = '3.wav'
# Audio(sound_file, autoplay=True)
# Out:
# LOS LEONES
#
# El león es uno de los felinos mos
# grandes del mundo. El león es un
# mamífero. Un mamífero quere decir
# (que tiene sangre tibia y pelaje. El
# león come carne porque es un
# 'carnivoro.  Elleón tiene una melena
# 'grande y peluda pora poder asustar
#
#
#
# ¡aotros animales. Elleón puede
# correr muy rápido para
#
# poder segur su presa.
#
# Los leones viven en
#
# grupos lamados
#
# manadas,
